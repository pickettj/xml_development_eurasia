# %%
import lxml.etree as ET

# %% [markdown]
# [stack overflow example](https://stackoverflow.com/questions/16698935/how-to-transform-an-xml-file-using-xslt-in-python)

# %% [markdown]
# seems not to work because lxml only reads XSLT 1.0; my script probably relies on 2.0

# %%
xml_filename =\
"../../../Dropbox/Active_Directories/Notes/Primary_Sources/xml_notes_stage3_final/bukhara_xml/ser934.xml"
xsl_filename = "../xslt/persian_document_reading_view_basic.xsl"

# %%
dom = ET.parse(xml_filename)
xslt = ET.parse(xsl_filename)
transform = ET.XSLT(xslt)
newdom = transform(dom)
print(ET.tostring(newdom, pretty_print=True))
# Out:
# ---------------------------------------------------------------------------
# XSLTParseError                            Traceback (most recent call last)
# <ipython-input-8-fc216ad3f589> in <module>
#       1 dom = ET.parse(xml_filename)
#       2 xslt = ET.parse(xsl_filename)
# ----> 3 transform = ET.XSLT(xslt)
#       4 newdom = transform(dom)
#       5 print(ET.tostring(newdom, pretty_print=True))
#
# src/lxml/xslt.pxi in lxml.etree.XSLT.__init__()
#
# XSLTParseError: xsl:value-of : could not compile select expression '                                             if ($id) then                                             concat($id, ': ')                                             else                                             (),                                             .'

# %%
f = open(xsl_filename, "r")
print(f.read())
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <xsl:stylesheet xmlns:xsl="http://www.w3.org/1999/XSL/Transform"
#     xmlns:xs="http://www.w3.org/2001/XMLSchema" exclude-result-prefixes="xs" version="2.0"
#     xmlns:prv="https://www.bactriana.org"
#     xmlns:xhtml="http://www.w3.org/1999/xhtml"
#     xmlns="http://www.w3.org/1999/xhtml">
#     <xsl:output method="xml" doctype-system="about:legacy-compat" indent="yes"/>
#
# <!-- ================================================================ -->
# <!-- Global Variables   -->
# <!-- ================================================================ -->
#     <!-- solution for getting unique ids with values (Birnbaum): https://github.com/obdurodon/dh_course/issues/459 -->
#     <xsl:variable name="locations" as="element(location)*" select="//location"/>
#
#
# <!-- ================================================================ -->
# <!-- Functions                                                        -->
# ...
